# %% [markdown]
# <a href="https://colab.research.google.com/github/automubashir/Fooocus/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone Fooocus repository
# !git clone https://github.com/automubashir/Fooocus.git
# %cd Fooocus
# Out:
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6527, done.
# remote: Total 6527 (delta 0), reused 0 (delta 0), pack-reused 6527 (from 1)
# Receiving objects: 100% (6527/6527), 33.25 MiB | 24.73 MiB/s, done.
# Resolving deltas: 100% (3706/3706), done.
# /content/Fooocus/Fooocus

# %%
# upgrade pip first (important in Colab)
# !pip install --upgrade pip

# install repo requirements
# !pip install -r requirements_versions.txt

# install compatible gradio version
# !pip install gradio==3.50.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 47.0 MB/s  0:00:00
# ...
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 0.5.0
#     Uninstalling gradio_client-0.5.0:
#       Successfully uninstalled gradio_client-0.5.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 3.41.2
#     Uninstalling gradio-3.41.2:
#       Successfully uninstalled gradio-3.41.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gradio]
# ...

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Version mismatch for gradio: Installed version 3.50.2 does not meet requirement gradio==3.41.2
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 1.33MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 1.30MB/s]
# ...
